# %%
using PowerModels

# %%
using Ipopt

# %%
result = run_opf("SV2027.raw", SOCWRPowerModel,with_optimizer(Ipopt.Optimizer))
# Out:
# [info | PowerModels]: The PSS(R)E parser currently supports buses, loads, shunts, generators, branches, transformers, and dc lines
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# [warn | PowerModels]: The following fields in GENERATOR are missing: O2, F2, O3, F3, O4, F4, WMOD, WPF
# ...

# %%
result
# Out:
# Dict{String,Any} with 10 entries:
#   "solve_time"         => 21.252
#   "optimizer"          => "Ipopt"
#   "termination_status" => LOCALLY_SOLVED
#   "dual_status"        => FEASIBLE_POINT
#   "primal_status"      => FEASIBLE_POINT
#   "objective"          => 2359.9
#   "solution"           => Dict{String,Any}("dcline"=>Dict{String,Any}("1"=>Dict…
#   "machine"            => Dict("cpu"=>"Intel(R) Core(TM) i7-7700HQ CPU @ 2.80GH…
#   "data"               => Dict{String,Any}("name"=>"sv2027","bus_count"=>2171,"…
#   "objective_lb"       => -Inf
